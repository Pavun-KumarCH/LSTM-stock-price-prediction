# %% [markdown]
# # LSTM Time Series - Stock Price Prediction
# ## Part 3 - Model Training
# In this notebook, we import the scaled dataset files, prepare them in a format suitable for LSTM modeling, and proceed to train the LSTM model.
#
# > **INPUT**: Scaled dataset files for training, validation, and testing periods, as processed in the preceding phase. <br/>
# > **OUTPUT**: Trained LSTM model and analysis of its performance.

# %% [markdown]
# ### 1. INITIALIZATION

# %%
# Import Necessary libraries and Modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense

from keras.callbacks import ModelCheckpoint
from keras.models import load_model

import joblib

# %% [markdown]
# ### 2. LOADING DATASETS

# %%
# Prepare data file location and Name
file_location = "..//data//processed//"
train_file_name = "google_stock_price_processed_train"
validation_file_name = "google_stock_price_processed_validation"
test_file_name = "google_stock_price_processed_test"
ext = "csv"

# Load data files
train_df = pd.read_csv(file_location + train_file_name + '.' + ext)
validation_df = pd.read_csv(file_location + validation_file_name + '.' + ext)
test_df = pd.read_csv(file_location + test_file_name + '.' + ext)

# %%
# Check loaded datasets shapes
print(f"Training Dataset Shape: {train_df.shape}")
print(f"Validation Dataset Shape: {validation_df.shape}")
print(f"Test Dataset Shape: {test_df.shape}")
# Out:
# Training Dataset Shape: (1132, 7)
# Validation Dataset Shape: (126, 7)
# Test Dataset Shape: (41, 7)

# %%
# Display a summaery of each dataset
print("Training Dataset:")
display(train_df.head())

print("Validation Dataset:")
display(validation_df.head())

print("Test Dataset:")
display(test_df.head())
# Out:
# Training Dataset:
#        Open      High       Low     Close  Adj Close    Volume        Date
# 0  0.000000  0.002422  0.001096  0.014909   0.014909  0.202348  2019-01-02
# 1  0.012090  0.004758  0.000269  0.000000   0.000000  0.254991  2019-01-03
# 2  0.007928  0.011707  0.006996  0.027351   0.027351  0.298130  2019-01-04
# 3  0.027184  0.013291  0.020776  0.026190   0.026190  0.279018  2019-01-07
# 4  0.029465  0.018586  0.023684  0.030138   0.030138  0.241988  2019-01-08
# Validation Dataset:
#        Open      High       Low     Close  Adj Close    Volume        Date
# 0  0.687796  0.688344  0.695774  0.698226   0.698226  0.059318  2023-07-03
# 1  0.685223  0.711909  0.699352  0.718946   0.718946  0.092952  2023-07-05
# 2  0.690964  0.689648  0.691188  0.701930   0.701930  0.092117  2023-07-06
# 3  0.693438  0.695665  0.699654  0.694022   0.694022  0.119846  2023-07-07
# 4  0.675424  0.668791  0.664880  0.661292   0.661292  0.222041  2023-07-10
# Test Dataset:
#        Open      High       Low     Close  Adj Close    Volume        Date
# 0  0.878621  0.884834  0.877559  0.888405   0.888405  0.112077  2024-01-02
# 1  0.868724  0.889597  0.884513  0.896413   0.896413  0.102712  2024-01-03
# 2  0.881096  0.885034  0.880280  0.873191   0.873191  0.096561  2024-01-04
# 3  0.866269  0.866734  0.868588  0.866685   0.866685  0.072499  2024-01-05
# 4  0.862785  0.885084  0.878970  0.898114   0.898114  0.091373  2024-01-08

# %% [markdown]
# ### 3. DATA PREPROCESSING
# The dataset has already undergone the primary preprocessing and transformation in the pervious phase. This section is only to display the data and extract features and dates.

# %%
# Convert Date columns to a valid Dattime Format
train_df["Date"] = pd.to_datetime(train_df["Date"])
validation_df["Date"] = pd.to_datetime(validation_df["Date"])
test_df["Date"] = pd.to_datetime(test_df["Date"])

# %%
# Extract dates from each datasets
train_dates = train_df["Date"]
validation_dates = validation_df["Date"]
test_dates = test_df["Date"]

# %%
# Extract Features
features = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]

train_scaled = train_df[features].values
validation_scaled = validation_df[features].values
test_scaled = test_df[features].values

# %% [markdown]
# ### 4. CONSTRUCTING DATA STRUCTURE
#
# Given that we are addressing a time series problem involving multiple predictors, our task involves constructing and reshaping the input data to suit the LSTM model.
#
# This entails setting a sliding time window (sequence size) that determines the number of past observations used to predict the subsequent value.
#
# In this experiment, we employ a sequence of previous samples (financial days) of all variables to forecast the opening price on the following day.

# %%
# Define a method to construct the inputs data X and Y
def construct_lstm_data(data, sequence_size, target_attr_idx):
    """ 
    Construct input data (X) and target data (y) for LSTM model from a pandas DataFrame.

    Parameters:
    -----------
    data : numpy.ndarray
        Input data array of shape (n_samples, n_features).
    
    sequence_size : int
        Number of previous time steps to use as input features for predicting the next time step.
    
    target_attr_idx : int
        Index of column in `data` DataFrame that corresponds to target attribute that LSTM model will predict.

    Returns:
    --------
    data_X : numpy.ndarray
        Array of LSTM input sequences of shape (n_samples - sequence_size, sequence_size, n_features).

    data_y : numpy.ndarray
        Corresponding target values for each input sequence of shape (n_samples - sequence_size,).
    """

    # Initializing constructed data variables
    data_X = []
    data_y = []

    # Iterate over the dataset
    for i in range(sequence_size, len(data)):
        data_X.append(data[i - sequence_size : i, 0 : data.shape[1]])
        data_y.append(data[i, target_attr_idx])
    
    # Return constructed variables
    return np.array(data_X), np.array(data_y)

# %% [markdown]
# The construction function is currently available for constructing subsets for training, validation, and testing date that is aligned with the LSTM model input.

# %%
# Define the sequence Size
sequence_size = 60

# Construct training data
X_train, y_train = construct_lstm_data(train_scaled, sequence_size, 0)

# %% [markdown]
# Because creating input data requires observations from previous samples, constructing subsets for the validation and testing periods suggests we append data from previous periods.
#
# For instance, to predict the initial stock price in the validation period, we must combine recent actual stock prices (sequence) from the training period. This step is crucial for providing the LSTM model with the expected sequence.
#
# Same principle applies to stock performance during the testing phase but in this case (and depending on the sequence size), we may need to combine samples from both validation and testing subsets.
#
# To facilitate this step, we combine the whole scaled dataset together and then select corresponding chunks before constructing the input data sets.

# %%
# Combine SScaled Datasets all together
all_scaled = np.concatenate([train_scaled, validation_scaled, test_scaled], axis = 0)

# Calculate data size
train_size = len(train_scaled)
validation_size = len(validation_scaled)
test_size = len(test_scaled)

# Construct validation dataset
X_validate, y_validate = construct_lstm_data(all_scaled[train_size - sequence_size : train_size + validation_size,:], sequence_size, 0)

# Construct testing dataset
X_test, y_test = construct_lstm_data(all_scaled[-(test_size + sequence_size):, :], sequence_size, 0)

# %%
# Check Original Data and Data Splits shapes
print(f'Full Scaled Data: {all_scaled.shape}')
print(f"\n Train Data Scaled : {train_scaled.shape}")
print(f"> Train X Data : {X_train.shape}")
print(f"> Train Y Data : {y_train.shape}")

print(f"\n Validation Data Scaled : {validation_scaled.shape}")
print(f"> Validation X Data : {X_validate.shape}")
print(f"> Validation Y Data : {y_validate.shape}")

print(f"\n Test Data Scaled : {test_scaled.shape}")
print(f"> Test X Data : {X_test.shape}")
print(f"> Test Y Data : {y_test.shape}")
# Out:
# Full Scaled Data: (1299, 6)
#
#  Train Data Scaled : (1132, 6)
# > Train X Data : (1072, 60, 6)
# > Train Y Data : (1072,)
#
#  Validation Data Scaled : (126, 6)
# > Validation X Data : (126, 60, 6)
# > Validation Y Data : (126,)
#
#  Test Data Scaled : (41, 6)
# > Test X Data : (41, 60, 6)
# > Test Y Data : (41,)

# %% [markdown]
# ### 5.  Building LSTM Model

# %%
# Initializing the model

model = Sequential()
# Add input layer
model.add(Input(shape = ( X_train.shape[1], X_train.shape[2] ))) 
# First LSTM
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(rate = 0.2))
# Second LSTM
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(rate = 0.2))
# Third LSTM
model.add(LSTM(units = 100, return_sequences = True))
model.add(Dropout(rate = 0.2))
# Forth LSTM
model.add(LSTM(100))
model.add(Dropout(rate = 0.2))
# Add Last Dense Layer
model.add(Dense(units = 1))


# Compiling the Model 
model.compile(optimizer = "adam",
              loss = "mean_squared_error")


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 100)        │        42,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 60, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 60, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 284,101 (1.08 MB)
#  Trainable params: 284,101 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### TRAINING LSTM MODEL

# %%
# Create a Checkpoint to Monitor the Validation Loss and Save the Model with the Best Performance.
model_location = "../models//"
model_name = "google_stock_price_lstm.model.keras"
best_model_checkpoint_callbacks = ModelCheckpoint(
                                                 model_location  + model_name,
                                                 monitor = "val_loss",
                                                 save_best_only = True,
                                                 mode = "min",
                                                 verbose = 0)

# %%
# Training the model
history = model.fit(
    x = X_train,
    y = y_train,
    validation_data = (X_validate, y_validate),
    epochs = 200,
    batch_size = 64,
    callbacks = [best_model_checkpoint_callbacks])
# Out:
# Epoch 1/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - loss: 0.0928 - val_loss: 0.0451
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - loss: 0.0135 - val_loss: 0.0030
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0062 - val_loss: 0.0029
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 12/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 13/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0033 - val_loss: 0.0027
# Epoch 14/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 15/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 16/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 17/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 18/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 19/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 20/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 21/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 22/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 23/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 24/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 25/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 26/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 27/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 28/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 29/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 30/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 31/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 32/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 33/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 34/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 35/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 36/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 37/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 38/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0023 - val_loss: 0.0034
# Epoch 39/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 40/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 41/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 42/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 43/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 44/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0022 - val_loss: 0.0015
# Epoch 45/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 46/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0022 - val_loss: 0.0014
# Epoch 47/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0025 - val_loss: 0.0015
# Epoch 48/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 49/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 50/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 51/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 52/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 53/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 54/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 55/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0021 - val_loss: 0.0013
# Epoch 56/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 57/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 58/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 59/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 60/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 61/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 62/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 64/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 65/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 66/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 67/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 68/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0022 - val_loss: 0.0010
# Epoch 69/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 70/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 71/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0018 - val_loss: 9.9091e-04
# Epoch 72/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 73/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0016 - val_loss: 9.6794e-04
# Epoch 74/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 75/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 76/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0019 - val_loss: 0.0010
# Epoch 77/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0017 - val_loss: 8.8835e-04
# Epoch 78/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0017 - val_loss: 9.2701e-04
# Epoch 79/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0020 - val_loss: 0.0050
# Epoch 80/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 81/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 82/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0015 - val_loss: 7.8684e-04
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0016 - val_loss: 8.4057e-04
# Epoch 84/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 85/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 86/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 87/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 88/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 89/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0020 - val_loss: 8.1448e-04
# Epoch 90/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0022 - val_loss: 8.3535e-04
# Epoch 92/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0014 - val_loss: 8.1574e-04
# Epoch 93/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 94/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0017 - val_loss: 7.5495e-04
# Epoch 95/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0013 - val_loss: 9.0845e-04
# Epoch 96/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0014 - val_loss: 8.2887e-04
# Epoch 97/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0013 - val_loss: 6.3116e-04
# Epoch 98/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.0013 - val_loss: 7.2248e-04
# Epoch 99/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0013 - val_loss: 5.9589e-04
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.0015 - val_loss: 8.8132e-04
# Epoch 101/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0014 - val_loss: 8.8033e-04
# Epoch 102/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 175ms/step - loss: 0.0013 - val_loss: 6.0275e-04
# Epoch 103/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 104/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 105/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 106/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 107/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 108/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 109/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 0.0018 - val_loss: 8.9585e-04
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0014 - val_loss: 5.0671e-04
# Epoch 111/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 0.0014 - val_loss: 5.5921e-04
# Epoch 112/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0011 - val_loss: 7.1650e-04
# Epoch 113/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.0013 - val_loss: 5.1876e-04
# Epoch 114/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - loss: 0.0011 - val_loss: 5.7033e-04
# Epoch 115/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0014 - val_loss: 7.6704e-04
# Epoch 116/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - loss: 0.0011 - val_loss: 4.9618e-04
# Epoch 117/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0013 - val_loss: 4.8624e-04
# Epoch 118/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0011 - val_loss: 5.6598e-04
# Epoch 119/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - loss: 0.0011 - val_loss: 4.5463e-04
# Epoch 120/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0011 - val_loss: 4.9654e-04
# Epoch 121/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 122/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0014 - val_loss: 5.8172e-04
# Epoch 123/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.0012 - val_loss: 5.0981e-04
# Epoch 124/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0012 - val_loss: 4.7237e-04
# Epoch 125/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0012 - val_loss: 8.6957e-04
# Epoch 126/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0011 - val_loss: 7.1197e-04
# Epoch 127/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 128/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: 0.0013 - val_loss: 5.2505e-04
# Epoch 129/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0012 - val_loss: 4.5995e-04
# Epoch 130/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0011 - val_loss: 7.7066e-04
# Epoch 131/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0012 - val_loss: 5.5272e-04
# Epoch 132/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0013 - val_loss: 8.1985e-04
# Epoch 133/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0011 - val_loss: 3.9177e-04
# Epoch 134/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0012 - val_loss: 3.6986e-04
# Epoch 135/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0011 - val_loss: 3.7687e-04
# Epoch 136/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: 0.0011 - val_loss: 5.7787e-04
# Epoch 137/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: 9.0658e-04 - val_loss: 8.7483e-04
# Epoch 138/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0013 - val_loss: 8.8635e-04
# Epoch 139/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0014 - val_loss: 4.2929e-04
# Epoch 140/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0011 - val_loss: 3.9950e-04
# Epoch 141/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0011 - val_loss: 7.8438e-04
# Epoch 142/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - loss: 0.0012 - val_loss: 8.1388e-04
# Epoch 143/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0011 - val_loss: 4.3353e-04
# Epoch 144/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 9.4019e-04 - val_loss: 3.5395e-04
# Epoch 145/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - loss: 0.0010 - val_loss: 3.5545e-04
# Epoch 146/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 0.0011 - val_loss: 6.7357e-04
# Epoch 147/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - loss: 0.0010 - val_loss: 4.8059e-04
# Epoch 148/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 0.0011 - val_loss: 4.0681e-04
# Epoch 149/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 9.1167e-04 - val_loss: 3.7850e-04
# Epoch 150/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 9.2972e-04 - val_loss: 3.4607e-04
# Epoch 151/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - loss: 9.8949e-04 - val_loss: 5.6459e-04
# Epoch 152/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 153/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0012 - val_loss: 4.3803e-04
# Epoch 154/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.5878e-04 - val_loss: 3.8725e-04
# Epoch 155/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.4426e-04 - val_loss: 3.6793e-04
# Epoch 156/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0010 - val_loss: 6.5192e-04
# Epoch 157/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0012 - val_loss: 4.2469e-04
# Epoch 158/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 9.2545e-04 - val_loss: 3.9239e-04
# Epoch 159/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 160/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 161/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0011 - val_loss: 6.4425e-04
# Epoch 162/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 0.0012 - val_loss: 4.6152e-04
# Epoch 163/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 9.8560e-04 - val_loss: 3.3962e-04
# Epoch 164/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 9.8716e-04 - val_loss: 4.2457e-04
# Epoch 165/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 0.0012 - val_loss: 3.7231e-04
# Epoch 166/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 8.8734e-04 - val_loss: 4.3290e-04
# Epoch 167/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 9.5616e-04 - val_loss: 3.1604e-04
# Epoch 168/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 9.1247e-04 - val_loss: 4.6345e-04
# Epoch 169/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 9.6184e-04 - val_loss: 3.5335e-04
# Epoch 170/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 9.3583e-04 - val_loss: 4.4212e-04
# Epoch 171/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 8.1163e-04 - val_loss: 5.8450e-04
# Epoch 172/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 9.4568e-04 - val_loss: 5.3052e-04
# Epoch 173/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 9.2924e-04 - val_loss: 3.2595e-04
# Epoch 174/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 0.0011 - val_loss: 3.9622e-04
# Epoch 175/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 7.6391e-04 - val_loss: 6.0159e-04
# Epoch 176/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - loss: 8.7332e-04 - val_loss: 3.2382e-04
# Epoch 177/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 8.9122e-04 - val_loss: 6.0564e-04
# Epoch 178/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 8.5680e-04 - val_loss: 4.3194e-04
# Epoch 179/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 8.9265e-04 - val_loss: 3.2871e-04
# Epoch 180/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 7.7916e-04 - val_loss: 8.8779e-04
# Epoch 181/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.1524e-04 - val_loss: 3.1531e-04
# Epoch 182/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0011 - val_loss: 5.2866e-04
# Epoch 183/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0010 - val_loss: 5.2205e-04
# Epoch 184/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.1821e-04 - val_loss: 3.2034e-04
# Epoch 185/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 9.8252e-04 - val_loss: 3.3633e-04
# Epoch 186/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 8.9313e-04 - val_loss: 3.4604e-04
# Epoch 187/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 9.7682e-04 - val_loss: 3.0196e-04
# Epoch 188/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 6.7495e-04 - val_loss: 3.7563e-04
# Epoch 189/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 0.0010 - val_loss: 3.8770e-04
# Epoch 190/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 8.8229e-04 - val_loss: 2.9024e-04
# Epoch 191/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 8.3976e-04 - val_loss: 3.6067e-04
# Epoch 192/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 9.5322e-04 - val_loss: 3.6052e-04
# Epoch 193/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0010 - val_loss: 3.7311e-04
# Epoch 194/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 7.7548e-04 - val_loss: 2.9753e-04
# Epoch 195/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 8.7274e-04 - val_loss: 3.8955e-04
# Epoch 196/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - loss: 7.8996e-04 - val_loss: 3.3099e-04
# Epoch 197/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 9.1948e-04 - val_loss: 0.0010
# Epoch 198/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 8.7043e-04 - val_loss: 4.5227e-04
# Epoch 199/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 9.3174e-04 - val_loss: 4.1461e-04
# Epoch 200/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - loss: 8.7845e-04 - val_loss: 2.9491e-04

# %% [markdown]
# #### Performance Evaluation

# %%
# Visulaization model Performance during training

plt.figure(figsize = (18,6))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("LSTM Model Performance")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The chart above highlights the following observations:
# - Training loss values decrease over the epochs, starting from a higher value and gradually decreasing. This indicates that the model is learning to fit the training data better as training progresses.
# - Similarly, the validation loss values also decrease initially, indicating improvement in the model's ability to generalize to unseen data (validation set).
# - Some fluctuations in the validation loss have been observed, which is quite justifiable due to the high variations and complexity in the price performance over time.
# - There are no signs of overfitting since both loss values are continuously decreasing along with each other over the epochs.
# - Validation loss has maintained lower values than training loss across almost the whole training period, which is quite normal due to the complexity/size of training data.

# %% [markdown]
# ### 6. MODEL INFERENCE
#
# The LSTM model has been trained and evaluated, making it ready to forecast future price trends.
#
# As mentioned earlier, we will employ our model to predict Google stock prices during the testing period. To thoroughly assess the model's performance, we will forecast stock performance for the entire period, including testing samples, and compare these predictions with actual prices.

# %% [markdown]
# #### Load Best Model

# %%
# Prepare model location and name
model_location = "..//models//"
model_name = "google_stock_price_lstm.model.keras"

# Load the best performance model
best_model = load_model(model_location + model_name)

# %% [markdown]
#  #### Model Prediction

# %%
# Predict stock price for all data splits
y_train_predict = best_model.predict(X_train)
y_validate_predict = best_model.predict(X_validate)
y_test_predict = best_model.predict(X_test)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# #### Inverse Scaling

# %% [markdown]
# One important thing to consider is the scale of the datasets, because the model was trained on scaled data that needs to be transformed back to its original price range.
#
# Therefore, we have to load the same scaler used for transforming the original dataset and apply it to restore the prediction outputs to their actual distribution.

# %%
# Prepare scaler model name and location
scaler_model_location = "..//models//"
scaler_model_name = "google_stock_price_scaler"
scaler_model_ext = "gz"

# Store the Scaler model
scale = joblib.load(scaler_model_location + scaler_model_name + "." + scaler_model_ext)

# %% [markdown]
# The scaler was initially fitted on data with 6 columns encompassing all the features considered. However, during the inverse transformation process, our focus is solely on transforming the "Open" price.
#
# To circumvent potential errors triggered by the inverse_transform API, we create a container structure of the necessary shape. We populate the first column with predictions and subsequently disregard the others.

# %%
# Restore actual distributions for predictied prices
y_train_inv = scale.inverse_transform(np.concatenate((y_train.reshape(-1,1), np.ones((len(y_train.reshape(-1,1)), 5))), axis = 1))[:,0]
y_validate_inv = scale.inverse_transform(np.concatenate((y_validate.reshape(-1,1), np.ones((len(y_validate.reshape(-1,1)), 5))), axis=1))[:,0]
y_test_inv = scale.inverse_transform(np.concatenate((y_test.reshape(-1,1), np.ones((len(y_test.reshape(-1,1)), 5))), axis=1))[:,0]

y_train_predict_inv = scale.inverse_transform(np.concatenate((y_train_predict, np.ones((len(y_train_predict), 5))), axis=1))[:,0]
y_validate_predict_inv = scale.inverse_transform(np.concatenate((y_validate_predict, np.ones((len(y_validate_predict), 5))), axis=1))[:,0]
y_test_predict_inv = scale.inverse_transform(np.concatenate((y_test_predict, np.ones((len(y_test_predict), 5))), axis=1))[:,0]

# %% [markdown]
# #### Display Predictions

# %%
# Define chart colors
train_actual_color = "cornflowerblue"
validation_actual_color = "orange"
test_actual_color = "green"

train_prediction_color = "lightblue"
validation_prediction_color = "peru"
test_prediction_color = "limegreen"

# %%
# Plot actual and Predictions
plt.figure(figsize = (18, 6))
plt.plot(train_dates[sequence_size:,], y_train_inv, label = "Training Actual", color = train_actual_color)
plt.plot(train_dates[sequence_size:,], y_train_predict_inv, label = "Training Predictions", linewidth = 1, color = train_prediction_color)

plt.plot(validation_dates, y_validate_inv, label="Validation Data", color=validation_actual_color)
plt.plot(validation_dates, y_validate_predict_inv, label="Validation Predictions", linewidth=1, color=validation_prediction_color)

plt.plot(test_dates, y_test_inv, label = "Test Actual", color = test_actual_color)
plt.plot(test_dates, y_test_predict_inv, label = "Test Predictions", linewidth = 1, color = test_prediction_color)


plt.title("Google Stock Price Predictions With LSTM")
plt.xlabel("Time")
plt.ylabel("Stock Price (USD)$")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval = 2))
plt.xticks(rotation = 45)
plt.legend()
plt.tight_layout()
plt.grid(color = "lightgray")
plt.show()

# %% [markdown]
# Based on this expanded overview, the model appears to perform very well throughout the observed period, with the predicted trend tends to align closely with actual stock performance across the three training, validation, and testing periods.
#
# To better assess the model's predictions during the validation and testing periods, let's inspect a zoomed-in version of this chart covering the most recent samples.

# %%
recent_samples = 50
plt.figure(figsize=(18,6))
plt.plot(train_dates[-recent_samples:,], y_train_inv[-recent_samples:,], label="Training Data", color=train_actual_color, linewidth=4)
plt.plot(train_dates[-recent_samples:,], y_train_predict_inv[-recent_samples:,], label="Training Predictions", linewidth=2, color=train_prediction_color)

plt.plot(validation_dates, y_validate_inv, label="Validation Data", color=validation_actual_color, linewidth=4)
plt.plot(validation_dates, y_validate_predict_inv, label="Validation Predictions", linewidth=2, color=validation_prediction_color)

plt.plot(test_dates, y_test_inv, label="Testing Data", color=test_actual_color, linewidth=4)
plt.plot(test_dates, y_test_predict_inv, label="Testing Predictions", linewidth=2, color=test_prediction_color)

plt.title("Google Stock Price Predictions With LSTM (last 50 financial days)")
plt.xlabel("Time")
plt.ylabel("Stock Price (USD)")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# plt.xticks(rotation=45)
plt.legend()
plt.grid(color="lightgray")

# %% [markdown]
# This closer look underscores the great performance of our LSTM model in predicting Google's stock prices during both validation and testing periods. Indicating the ability of this model to generalize on unseen data that was not included in the training set.
#
# Despite the exact value predictions might be slightly different from real prices, the strong performance of this model is primarily derived from its ability to consistently mirror the actual trends across almost all phases. This is the most significant takeaway of stock price predictions analysis.
